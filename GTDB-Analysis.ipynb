# %% [markdown]
# <a href="https://colab.research.google.com/github/MirandaCJohnson/GlobalTerrorismData/blob/master/GTDB-Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd
import numpy as np

dataset="https://raw.githubusercontent.com/MirandaCJohnson/GlobalTerrorismData/master/GTDB-v03232019.csv"
table=pd.read_csv(dataset)

# %%
df=pd.DataFrame(data=table)

df.head(3)
# Out:
#    eventid  year    country_txt    provstate  \
# 0        2  1970  United States   New Jersey
# 1        3  1970  United States  Mississippi
# 2        4  1970  United States   Washington
#
#                                              summary  \
# 0  1/19/1970: Unknown perpetrators ignited a fire...
# 1  1/25/1970: Unknown perpetrators burnt down a b...
# 2  1/28/1970: Unknown perpetrators detonated an e...
#
#                   attacktype1_txt                   targtype1_txt  \
# 0  Facility/Infrastructure Attack         Violent Political Party
# 1  Facility/Infrastructure Attack     Private Citizens & Property
# 2               Bombing/Explosion  Religious Figures/Institutions
#
#             targsubtype1_txt    natlty1_txt             gname  \
# 0      Party Office/Facility  United States  White extremists
# 1  Race/Ethnicity Identified  United States  White extremists
# 2           Place of Worship  United States  White extremists
#
#                    nperps  Unnamed: 11
# ...

# %%
table.tail(3)
# Out:
#      eventid  year    country_txt   provstate  \
# 127      129  2017  United States    Nebraska
# 128      130  2017  United States   Louisiana
# 129      131  2017  United States  New Mexico
#
#                                                summary  \
# 127  10/22/2017: An assailant breached a secure are...
# 128  10/31/2017: An assailant set fire to the predo...
# 129  12/07/2017: An assailant, identified as Willia...
#
#                     attacktype1_txt                   targtype1_txt  \
# 127                   Armed Assault                  Transportation
# 128  Facility/Infrastructure Attack  Religious Figures/Institutions
# 129                   Armed Assault         Educational Institution
#
#                            targsubtype1_txt    natlty1_txt             gname  \
# 127              Train/Train Tracks/Trolley  United States  White extremists
# 128                        Place of Worship  United States  White extremists
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

print("Total of White Extremist Terrorist attacks in the USA by Group from 1970-2017")
table['gname'].value_counts().plot(kind="pie", figsize=(6,18))
# Out:
# Total of White Extremist Terrorist attacks in the USA by Group from 1970-2017

# %%
print('Frequency of Attack Methods')
table["nperps"].value_counts().plot(kind="bar")
# Out:
# Frequency of Attack Methods

# %%
# 03/24/2019
# ********* Pie chart of all white extremist terror attacks in the USA 1970-2017


labels=df['gname'].unique()
#print (labels)

#***  Find the total number of attacks
total_attacks=df['eventid'].count()
#print(total_attacks)

#***  Find total number of attacks per each extremist group.  
#***  (Divide by total_attacks)*100 for percentages to use in pie chart sizes
total_by_group=df.gname.value_counts()
#print(total_by_group)

we=(total_by_group[0]/total_attacks)*100
kkk=(total_by_group[1]/total_attacks)*100
nne=(total_by_group[2]/total_attacks)*100
ar=(total_by_group[3]/total_attacks)*100
wpp=(total_by_group[4]/total_attacks)*100

#print(we, kkk, nne, ar, wpp)

#***  Pie chart with labels and proportionally correct sections
sizes=[we, kkk, nne, ar, wpp]

colors=['#a58863', '#2996a7', '#d7cc88', '#adc835', '#3bc123']

fig1, ax1 = plt.subplots()
ax1.pie(sizes, colors=colors, labels=labels, autopct='%.1f%%', startangle=90)

ax1.axis('equal')
plt.tight_layout()
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# Why is fig1 needed in fig1, ax1 = plt.subplots()  ?  ##fig1 is not used anywhere else in the code but with out it and error is thrown:  'tuple' object has no attribute 'pie'

# %%
#03/24/2019

x=df['year'].unique()
#print(x)

y=df.year.value_counts()
#print(y)

#df.plot(kind="scatter", x=x, y=y)
table['year'].value_counts().plot(kind='bar', figsize=(12,8))

#plt.scatter[x,y]
plt.title("Attacks per Year in USA 1970-2017, ordered from greatest to least number of attacks per year")
# plt.xlabel("Year")
# plt.ylabel("Group Name")
# Out:
# Text(0.5, 1.0, 'Attacks per Group in USA 1970-2017')
